# %%
df = spark.read.csv("/Volumes/trips/landing/trips", header=True, inferSchema=True)
display(df)

# %%
import os

file_path = "/Volumes/trips/landing/trips"
exists = os.path.exists(file_path)
print(f"Le fichier existe: {exists}")
